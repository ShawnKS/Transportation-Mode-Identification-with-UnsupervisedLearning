# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(4,32,(3,1))
        self.conv2 = nn.Conv2d(32,32,(3,1))
        self.pool1 = nn.MaxPool2d((2,1))
        self.conv3 = nn.Conv2d(32,64,(3,1))
        self.conv4 = nn.Conv2d(64,64,(3,1))
        self.pool2 = nn.MaxPool2d((2,1))
        self.conv5 = nn.Conv2d(64,128,(3,1))
        self.conv6 = nn.Conv2d(128,128,(3,1))
        self.pool3 = nn.MaxPool2d((2,1))
        self.relu = nn.ReLU()
        self.fc = nn.Linear(27*128,5)
        # self.logsoftmax = nn.LogSoftmax()


    def forward(self, x):

        out = self.relu(self.conv1(x))
        out = self.relu(self.conv2(out))
        out = self.pool1(out)
        # print(np.shape(out))
        out = self.relu(self.conv3(out))
        out = self.relu(self.conv4(out))
        out = self.pool2(out)
        out = self.relu(self.conv5(out))
        out = self.relu(self.conv6(out))
        out = self.pool3(out)
        # print(np.shape(out))
        out = out.view(-1, 27*128)
        # print(np.shape(out))
        # sys.exit(0)
        out = self.fc(out)
        # out = self.logsoftmax(out)
        # out = F.sigmoid(out)
        # print(out)
        # print(np.shape(out))
        # sys.exit(0)
        
        return(out)


net = Net()
print(net)
# Out:
# Net(
#   (conv1): Conv2d(4, 32, kernel_size=(3, 1), stride=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 1), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 1), stride=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 1), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#   (conv5): Conv2d(64, 128, kernel_size=(3, 1), stride=(1, 1))
#   (conv6): Conv2d(128, 128, kernel_size=(3, 1), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (fc): Linear(in_features=3456, out_features=5, bias=True)
# )

# %%
params = list(net.parameters())
print(len(params))
print(params[0].size())  # conv1's .weight
# Out:
# 14
# torch.Size([32, 4, 3, 1])

# %%
input = torch.randn(1, 4, 248, 1)
print(input)
out = net(input)
print(out)
# Out:
# tensor([[[[-1.5408e+00],
#           [ 1.3037e-01],
#           [ 5.8385e-01],
#           [ 2.4157e-01],
#           [-9.9370e-01],
#           [-1.1804e-01],
#           [ 9.3748e-01],
#           [ 1.4901e+00],
#           [ 7.0510e-01],
#           [-1.6656e+00],
#           [-1.3417e+00],
#           [-1.4621e+00],
#           [ 3.8347e-01],
#           [ 5.5094e-01],
#           [-8.1841e-01],
#           [ 1.0242e+00],
#           [ 1.0638e-01],
#           [ 2.2036e-01],
#           [-1.5609e-01],
#           [-9.3844e-01],
#           [-1.2712e+00],
#           [-1.0813e+00],
#           [-1.4908e+00],
#           [ 1.2996e+00],
#           [-1.4186e+00],
#           [ 8.6450e-01],
#           [-1.2275e+00],
#           [-7.6108e-01],
#           [ 9.6732e-02],
#           [-6.9538e-01],
#           [-1.6624e+00],
#           [ 3.6011e-01],
#           [ 2.8036e+00],
#           [ 4.3431e-01],
#           [-1.5333e-01],
#           [ 1.4120e+00],
#           [ 1.4384e+00],
#           [ 8.9601e-01],
#           [ 2.8682e-01],
#           [-2.4549e-01],
#           [ 2.5445e+00],
#           [-1.5712e-01],
#           [-7.5142e-01],
#           [-5.1508e-01],
#           [ 1.1276e+00],
#           [ 8.0763e-01],
#           [-8.1672e-01],
#           [-5.9777e-01],
#           [ 9.3946e-02],
#           [ 1.3422e+00],
#           [-2.0273e-01],
#           [ 1.6387e+00],
#           [-8.2522e-01],
#           [-1.5994e+00],
#           [-6.7254e-01],
#           [ 9.6652e-01],
#           [-3.2406e+00],
#           [-1.8484e-01],
#           [-2.4527e-01],
#           [ 1.6799e+00],
#           [-4.7271e-01],
#           [ 1.4483e+00],
#           [-2.7678e-01],
#           [ 1.8950e+00],
#           [ 1.1865e+00],
#           [ 1.3310e-01],
#           [ 2.2194e+00],
#           [-6.9798e-01],
#           [ 2.9166e-01],
#           [-3.9357e-01],
#           [ 5.1188e-01],
#           [-1.1412e+00],
#           [ 1.6109e+00],
#           [-3.1679e-02],
#           [-1.5270e+00],
#           [-3.4496e-01],
#           [-2.9659e-01],
#           [-2.6742e-01],
#           [-8.4877e-01],
#           [-4.7959e-01],
#           [-4.4110e-01],
#           [-8.4990e-01],
#           [ 8.9730e-02],
#           [ 6.6731e-01],
#           [ 3.4603e-01],
#           [ 1.8257e+00],
#           [ 9.4106e-01],
#           [-8.8035e-01],
#           [-8.3885e-01],
#           [ 2.3243e-02],
#           [ 1.6467e+00],
#           [ 1.5222e+00],
#           [ 8.1206e-01],
#           [-9.9502e-01],
#           [ 1.1690e+00],
#           [-8.0052e-01],
#           [ 3.7266e-01],
#           [ 4.5905e-02],
#           [ 1.4158e-01],
#           [ 1.9327e+00],
#           [ 1.2620e-01],
#           [-7.9867e-01],
#           [-7.9553e-01],
#           [-4.2786e-01],
#           [ 2.3887e-01],
#           [ 4.5522e-01],
#           [ 5.8201e-01],
#           [-1.6783e-01],
#           [ 1.1111e+00],
#           [-6.5569e-01],
#           [-1.7080e+00],
#           [-8.0591e-01],
#           [-9.2774e-01],
#           [ 7.3078e-01],
#           [ 5.9831e-02],
#           [ 1.0175e+00],
#           [-9.9489e-01],
#           [ 1.2748e+00],
#           [-1.8157e-01],
#           [ 7.1234e-01],
#           [-4.6377e-01],
#           [ 5.0382e-01],
#           [ 5.6790e-01],
#           [-2.6804e-01],
#           [-4.4271e-01],
#           [ 9.8879e-01],
#           [ 3.9462e-01],
#           [ 6.8341e-01],
#           [ 7.7431e-01],
#           [-2.3552e+00],
#           [ 3.7481e-01],
#           [ 1.0541e-01],
#           [-3.9562e-01],
#           [-5.0146e-01],
#           [ 9.8553e-01],
#           [ 5.5764e-01],
#           [-2.4033e-01],
#           [-1.9009e+00],
#           [ 9.9189e-01],
#           [ 1.4553e+00],
#           [ 1.3891e+00],
#           [-1.0990e+00],
#           [-2.0428e-01],
#           [-6.2405e-01],
#           [-7.8559e-01],
#           [ 9.2962e-01],
#           [ 1.6120e+00],
#           [-9.3781e-01],
#           [ 4.2706e-01],
#           [ 2.9069e-01],
#           [-2.5280e+00],
#           [-1.1799e+00],
#           [-1.6664e-01],
#           [-1.7234e+00],
#           [-7.9806e-01],
#           [ 4.0211e-01],
#           [ 9.8664e-01],
#           [-3.7337e-01],
#           [-4.3922e-02],
#           [-1.0127e+00],
#           [ 6.0507e-01],
#           [ 3.9194e-01],
#           [ 6.4147e-01],
#           [-1.2214e+00],
#           [ 5.6142e-01],
#           [ 4.9956e-01],
#           [-7.2166e-01],
#           [ 7.9208e-01],
#           [ 1.6170e+00],
#           [ 1.2865e+00],
#           [-8.1866e-02],
#           [-1.0708e+00],
#           [-9.5557e-01],
#           [ 6.1921e-01],
#           [ 3.7178e-01],
#           [-4.6473e-01],
#           [-4.1338e-01],
#           [ 1.0965e+00],
#           [-1.0205e+00],
#           [ 1.5074e-01],
#           [ 8.8445e-01],
#           [-2.2814e-01],
#           [-1.0286e+00],
#           [-1.9170e-01],
#           [-3.9397e-01],
#           [ 9.3313e-01],
#           [ 9.0744e-01],
#           [-5.0947e-01],
#           [ 9.4707e-01],
#           [ 1.2795e+00],
#           [ 1.0377e+00],
#           [-2.0738e+00],
#           [ 1.4389e-01],
#           [-1.7321e+00],
#           [ 7.5642e-01],
#           [ 8.5795e-01],
#           [ 7.3844e-01],
#           [ 9.7084e-02],
#           [ 9.3585e-01],
#           [ 2.7990e-01],
#           [-1.8870e-01],
#           [ 6.6726e-01],
#           [ 1.0376e+00],
#           [ 8.2927e-01],
#           [-1.4333e+00],
#           [-6.5301e-01],
#           [ 6.6916e-01],
#           [ 6.9179e-01],
#           [-8.8089e-01],
#           [-9.0610e-01],
#           [-4.0081e-02],
#           [-3.2955e-01],
#           [ 9.4829e-01],
#           [ 6.0105e-01],
#           [-9.5454e-01],
#           [ 1.3541e+00],
#           [-6.7761e-01],
#           [ 5.0855e-01],
#           [ 5.4437e-01],
#           [ 1.2954e+00],
#           [ 5.7201e-01],
#           [-1.1280e+00],
#           [-5.8830e-01],
#           [-1.6527e+00],
#           [-4.3605e-01],
#           [-5.0025e-01],
#           [ 8.7263e-01],
#           [-9.6498e-01],
#           [ 4.5127e-01],
#           [ 8.2696e-01],
#           [ 1.8581e-01],
#           [-7.8097e-01],
#           [ 5.1721e-01],
#           [ 1.3391e+00],
#           [-1.0652e+00],
#           [ 7.4173e-01],
#           [ 5.5913e-01],
#           [ 4.6794e-01],
#           [ 6.7035e-01],
#           [ 1.4981e-01],
#           [ 6.5122e-01],
#           [ 6.7082e-02],
#           [-2.5313e+00],
#           [-6.7739e-01],
#           [-1.8784e+00],
#           [ 9.4585e-01],
#           [ 1.4006e+00],
#           [-6.8368e-01]],
#
#          [[-8.4483e-01],
#           [ 5.2007e-01],
#           [-8.3839e-01],
#           [-7.0585e-01],
#           [-1.0357e+00],
#           [ 8.0900e-01],
#           [ 9.7900e-01],
#           [ 2.1431e-01],
#           [ 8.5951e-01],
#           [ 1.0279e+00],
#           [-7.0822e-01],
#           [ 2.1416e+00],
#           [-1.9788e+00],
#           [-2.2344e+00],
#           [ 7.0882e-01],
#           [-1.9656e-01],
#           [-1.0305e+00],
#           [ 5.1275e-01],
#           [-8.3415e-02],
#           [ 2.4858e-01],
#           [-1.2180e+00],
#           [ 1.7787e-01],
#           [ 1.0707e+00],
#           [-7.0041e-01],
#           [ 1.9149e+00],
#           [ 1.3421e+00],
#           [-6.1514e-01],
#           [-4.3434e-01],
#           [ 2.4354e-02],
#           [ 1.9485e+00],
#           [ 1.5740e-02],
#           [ 3.2612e-01],
#           [-8.5761e-01],
#           [ 8.8558e-01],
#           [ 6.2795e-01],
#           [ 8.6239e-01],
#           [ 1.6206e+00],
#           [ 1.5483e+00],
#           [-1.3262e+00],
#           [ 1.7099e-01],
#           [-2.9597e-02],
#           [ 1.7632e+00],
#           [ 1.0828e+00],
#           [ 5.2326e-01],
#           [ 1.6849e+00],
#           [-6.6871e-01],
#           [ 1.3692e+00],
#           [ 3.6271e-01],
#           [ 5.6310e-01],
#           [-1.2049e+00],
#           [ 1.8062e-01],
#           [ 1.3840e+00],
#           [ 1.3745e+00],
#           [-6.5729e-01],
#           [ 8.9918e-01],
#           [ 7.1414e-01],
#           [ 1.8645e+00],
#           [-8.1121e-01],
#           [ 8.5612e-01],
#           [-4.3463e-01],
#           [ 1.4997e+00],
#           [-1.0041e+00],
#           [-3.4871e-01],
#           [ 4.0933e-01],
#           [ 1.6518e+00],
#           [-7.8878e-01],
#           [ 1.1551e+00],
#           [ 7.5863e-02],
#           [ 7.2458e-01],
#           [-1.8009e-01],
#           [ 1.4492e+00],
#           [ 1.4235e+00],
#           [-1.2916e+00],
#           [-4.8666e-01],
#           [ 7.6825e-01],
#           [ 9.6571e-02],
#           [-1.0843e+00],
#           [-8.2061e-01],
#           [ 1.9688e+00],
#           [-1.9746e-01],
#           [ 7.3272e-01],
#           [ 1.3226e+00],
#           [-2.1784e-01],
#           [-5.6408e-01],
#           [-8.3601e-01],
#           [-3.8661e-01],
#           [ 6.6679e-01],
#           [ 1.7311e+00],
#           [ 1.6413e+00],
#           [ 1.6758e-01],
#           [-6.0305e-01],
#           [-8.2975e-01],
#           [ 3.5076e-01],
#           [-1.3579e+00],
#           [ 9.1394e-01],
#           [ 1.5076e-01],
#           [ 4.3556e-02],
#           [-1.1935e-01],
#           [-1.0951e+00],
#           [-1.4842e-01],
#           [ 1.9783e-01],
#           [-7.2596e-01],
#           [ 3.7530e-01],
#           [ 7.2135e-02],
#           [-8.8111e-01],
#           [-1.7617e+00],
#           [ 7.1610e-01],
#           [-4.0209e-01],
#           [ 7.0290e-01],
#           [-6.7132e-01],
#           [ 1.5139e+00],
#           [ 2.0096e-01],
#           [-1.6764e-02],
#           [ 7.1360e-01],
#           [-1.6560e+00],
#           [-1.2904e+00],
#           [-1.2473e+00],
#           [ 4.2712e-01],
#           [-1.8363e-01],
#           [ 1.2884e+00],
#           [ 1.7943e-01],
#           [ 5.1020e-01],
#           [ 1.7043e+00],
#           [ 2.3801e-01],
#           [ 6.6613e-01],
#           [-1.0379e+00],
#           [ 6.9497e-01],
#           [ 3.6691e-01],
#           [-7.0958e-01],
#           [-5.5754e-01],
#           [ 7.6457e-01],
#           [-6.0208e-01],
#           [-3.6303e-01],
#           [-2.4976e+00],
#           [ 1.1659e+00],
#           [-7.4798e-01],
#           [ 8.9147e-01],
#           [-2.4617e+00],
#           [ 1.1883e+00],
#           [-6.0326e-01],
#           [ 7.5913e-01],
#           [ 1.1393e-01],
#           [-1.6892e+00],
#           [ 6.5785e-01],
#           [ 4.3983e-01],
#           [-4.6375e-01],
#           [ 1.9991e+00],
#           [ 4.6426e-01],
#           [-9.5515e-01],
#           [ 9.4615e-02],
#           [ 1.2107e+00],
#           [-9.8520e-03],
#           [-8.9062e-01],
#           [-8.5967e-01],
#           [ 7.0494e-01],
#           [-4.7477e-01],
#           [ 1.8273e+00],
#           [ 7.9358e-01],
#           [ 5.1353e-01],
#           [ 8.6547e-02],
#           [ 9.7197e-01],
#           [-6.5335e-02],
#           [-7.8374e-01],
#           [ 9.5644e-01],
#           [ 9.6683e-01],
#           [ 1.2549e+00],
#           [ 1.6745e-01],
#           [ 4.3062e-01],
#           [-1.9657e+00],
#           [-6.1497e-01],
#           [ 1.0199e+00],
#           [-1.2317e-01],
#           [ 3.9971e-02],
#           [ 5.1668e-01],
#           [ 1.9854e+00],
#           [ 8.3997e-01],
#           [-4.7992e-01],
#           [-1.7455e+00],
#           [-5.6322e-01],
#           [ 5.4413e-01],
#           [ 8.4000e-01],
#           [-9.8308e-01],
#           [ 2.7716e-01],
#           [ 1.2778e+00],
#           [ 7.0047e-01],
#           [ 3.3214e-01],
#           [-8.5672e-01],
#           [ 2.8216e-01],
#           [-4.2102e-01],
#           [ 5.9168e-01],
#           [-1.1575e+00],
#           [ 6.2421e-01],
#           [-2.6837e-01],
#           [ 9.7356e-02],
#           [ 1.2440e+00],
#           [ 5.8487e-01],
#           [ 1.2192e+00],
#           [ 1.4580e+00],
#           [ 4.5499e-01],
#           [-8.3526e-01],
#           [ 7.1579e-01],
#           [-7.4777e-01],
#           [ 8.3776e-01],
#           [ 1.7620e+00],
#           [ 2.6429e-01],
#           [-1.7160e+00],
#           [-1.1063e+00],
#           [-4.1446e-01],
#           [-3.0993e-02],
#           [ 3.9882e-01],
#           [ 4.3903e-01],
#           [-1.3352e+00],
#           [ 1.6883e+00],
#           [-5.1779e-02],
#           [ 1.2962e+00],
#           [-1.0735e-01],
#           [ 3.7817e-01],
#           [-8.3548e-01],
#           [ 2.8591e-01],
#           [ 3.0815e-01],
#           [-4.0696e-01],
#           [ 3.9371e-01],
#           [ 7.6457e-01],
#           [-1.1015e+00],
#           [ 4.4035e-01],
#           [-1.3752e-01],
#           [-4.7432e-01],
#           [-7.8987e-01],
#           [ 4.6705e-01],
#           [-2.3936e+00],
#           [ 7.5588e-01],
#           [ 3.4801e-02],
#           [-8.0854e-01],
#           [-4.5485e-01],
#           [-1.1162e+00],
#           [-2.3344e-01],
#           [-9.5536e-01],
#           [ 8.8326e-01],
#           [ 5.6138e-01],
#           [ 3.7740e-01],
#           [ 3.5796e-01],
#           [ 5.6746e-01],
#           [-2.2289e-01],
#           [ 2.2897e-01],
#           [ 3.9874e-01],
#           [-7.5538e-02],
#           [ 1.8034e+00],
#           [ 1.7275e-01]],
#
#          [[-9.0813e-01],
#           [-1.8947e+00],
#           [ 2.5404e-01],
#           [-1.4839e+00],
#           [ 1.6812e+00],
#           [ 5.0871e-01],
#           [-7.8801e-01],
#           [-1.2011e+00],
#           [ 1.2343e+00],
#           [-8.2251e-01],
#           [-7.8921e-01],
#           [-4.8638e-01],
#           [-2.0988e-01],
#           [-1.4878e+00],
#           [-1.8472e+00],
#           [-1.1853e+00],
#           [ 7.2486e-01],
#           [ 1.8395e+00],
#           [ 3.5230e-01],
#           [-2.2845e-01],
#           [-5.9232e-01],
#           [-2.5687e-01],
#           [-7.7846e-01],
#           [-1.4280e+00],
#           [ 1.9727e+00],
#           [ 4.4356e-02],
#           [ 3.9068e-01],
#           [ 3.1429e-02],
#           [ 2.4420e+00],
#           [ 6.5465e-01],
#           [ 2.8527e-01],
#           [ 1.2380e+00],
#           [ 9.6632e-01],
#           [-2.8011e+00],
#           [-1.0637e-01],
#           [-1.1514e+00],
#           [-4.1539e-01],
#           [ 6.4547e-01],
#           [-1.4048e+00],
#           [-1.6800e+00],
#           [-3.9700e-01],
#           [ 1.1193e+00],
#           [ 2.1398e-01],
#           [-2.0813e+00],
#           [-1.0038e+00],
#           [-4.2553e-01],
#           [ 2.0230e+00],
#           [ 1.1259e-01],
#           [-2.0296e-01],
#           [ 6.2137e-01],
#           [ 9.8499e-01],
#           [ 3.1527e-01],
#           [-1.3506e+00],
#           [ 4.3332e-01],
#           [-5.7063e-01],
#           [ 5.8374e-01],
#           [-5.8706e-01],
#           [ 2.3106e+00],
#           [-9.6971e-01],
#           [ 3.6928e-01],
#           [ 3.0790e-01],
#           [-7.3774e-01],
#           [-7.4965e-01],
#           [ 1.1193e+00],
#           [ 7.5956e-01],
#           [-1.1250e+00],
#           [ 1.2386e+00],
#           [ 1.8006e+00],
#           [ 4.1589e-03],
#           [ 1.2589e+00],
#           [-3.2761e-02],
#           [ 8.4592e-02],
#           [-6.7543e-01],
#           [-3.4007e-01],
#           [ 2.0734e+00],
#           [ 3.7148e-01],
#           [-2.4520e+00],
#           [-1.6455e-02],
#           [ 1.0155e+00],
#           [ 2.0464e+00],
#           [ 6.6338e-01],
#           [ 7.5449e-01],
#           [-5.7821e-02],
#           [ 5.7492e-01],
#           [-1.0122e+00],
#           [ 2.9753e+00],
#           [-1.1082e+00],
#           [-6.6124e-02],
#           [-5.9790e-01],
#           [ 3.3799e-01],
#           [ 1.9521e-01],
#           [ 1.7550e+00],
#           [ 1.0455e+00],
#           [ 1.8853e-01],
#           [-3.2247e-01],
#           [-6.4674e-01],
#           [ 1.3063e+00],
#           [-2.2278e-01],
#           [ 1.6835e+00],
#           [-1.4612e+00],
#           [-6.9861e-01],
#           [-5.4348e-01],
#           [ 9.4214e-01],
#           [-1.0667e+00],
#           [-9.4299e-01],
#           [-5.2189e-01],
#           [-1.0800e+00],
#           [ 8.5655e-01],
#           [ 8.9618e-01],
#           [-1.2748e-01],
#           [ 1.4533e+00],
#           [-1.2069e+00],
#           [-7.6776e-01],
#           [ 1.1856e-01],
#           [-5.9504e-01],
#           [ 5.4537e-01],
#           [-1.4884e-01],
#           [ 1.2788e+00],
#           [-3.0038e-01],
#           [-6.2492e-03],
#           [ 1.0778e+00],
#           [-9.0249e-01],
#           [-2.5019e-01],
#           [-1.0187e-01],
#           [ 1.9451e-01],
#           [ 5.9903e-01],
#           [-1.3211e+00],
#           [ 1.6021e+00],
#           [ 8.8575e-02],
#           [-8.5900e-01],
#           [ 1.6573e-01],
#           [ 1.9010e+00],
#           [ 5.0623e-02],
#           [-1.8646e+00],
#           [ 1.1398e+00],
#           [ 2.5058e-01],
#           [ 3.1435e-01],
#           [-1.0926e+00],
#           [-6.6226e-01],
#           [-5.9690e-01],
#           [-3.0638e-01],
#           [-6.4677e-01],
#           [ 1.1293e+00],
#           [-1.8226e+00],
#           [-1.5532e-01],
#           [ 8.5867e-01],
#           [-4.2704e-01],
#           [-8.4073e-01],
#           [ 2.7637e-02],
#           [ 2.1958e+00],
#           [ 7.8697e-01],
#           [-1.4350e+00],
#           [-3.0906e-01],
#           [ 2.3969e+00],
#           [ 1.2177e+00],
#           [ 6.5831e-01],
#           [-4.5395e-01],
#           [-8.6090e-01],
#           [ 8.2466e-01],
#           [-1.4747e+00],
#           [ 6.5645e-01],
#           [ 4.6851e-01],
#           [-1.5924e+00],
#           [-3.2323e-01],
#           [ 1.7383e+00],
#           [-7.9934e-01],
#           [-5.0850e-01],
#           [-6.6244e-01],
#           [ 1.9098e-01],
#           [-1.4495e-02],
#           [-4.9417e-01],
#           [ 4.6914e-01],
#           [-5.7831e-02],
#           [-1.6086e+00],
#           [ 7.7041e-02],
#           [ 9.4525e-01],
#           [-6.4182e-02],
#           [ 2.5817e-01],
#           [-6.8638e-01],
#           [-1.0205e+00],
#           [-6.5490e-02],
#           [-4.3469e-01],
#           [-2.3450e-03],
#           [-6.1450e-01],
#           [-9.7245e-01],
#           [-1.4336e+00],
#           [-1.6634e-01],
#           [ 6.9709e-01],
#           [ 2.4563e-01],
#           [ 1.2648e+00],
#           [ 9.0720e-01],
#           [-7.9760e-01],
#           [-2.3191e+00],
#           [ 3.9327e-01],
#           [-2.4311e-02],
#           [-1.1246e+00],
#           [-1.2584e+00],
#           [-1.8864e-01],
#           [-9.2151e-03],
#           [-4.7061e-02],
#           [-5.4960e-01],
#           [-1.3804e-01],
#           [-1.9737e+00],
#           [-8.9775e-01],
#           [ 1.5205e+00],
#           [ 6.3975e-01],
#           [ 6.3959e-01],
#           [ 7.0569e-02],
#           [ 4.8703e-01],
#           [ 1.0616e+00],
#           [ 3.7084e-01],
#           [-4.8226e-01],
#           [-2.2984e-01],
#           [ 3.5991e-01],
#           [-2.5468e-01],
#           [ 4.7537e-01],
#           [-1.1344e+00],
#           [ 1.3495e-01],
#           [ 5.4293e-01],
#           [-2.1280e-01],
#           [-2.9283e+00],
#           [-1.2612e+00],
#           [-2.0710e-01],
#           [-1.1348e+00],
#           [-6.8916e-01],
#           [-4.5714e-01],
#           [ 2.5431e-01],
#           [ 3.2328e-01],
#           [-1.9871e+00],
#           [ 1.5428e+00],
#           [-1.5799e+00],
#           [-2.0100e-01],
#           [ 1.7780e-02],
#           [ 2.1107e-01],
#           [-1.1940e-01],
#           [-1.4562e+00],
#           [ 2.6462e-03],
#           [ 7.7454e-01],
#           [ 7.9771e-01],
#           [-5.2802e-01],
#           [-1.6061e+00],
#           [ 1.5188e-01],
#           [-4.1631e-01],
#           [-3.0934e-01],
#           [-1.9351e+00],
#           [-3.5654e-01],
#           [ 5.9514e-01],
#           [ 1.2986e-01]],
#
#          [[-1.7939e-01],
#           [ 2.5342e-01],
#           [ 1.4765e+00],
#           [ 7.9804e-01],
#           [ 2.1829e-01],
#           [ 6.5328e-01],
#           [-5.2604e-01],
#           [ 8.1012e-01],
#           [ 5.6371e-01],
#           [-1.4708e+00],
#           [-6.1122e-02],
#           [-4.3539e-01],
#           [-9.2446e-01],
#           [ 5.6291e-01],
#           [-7.4412e-01],
#           [-1.3242e+00],
#           [-1.1996e+00],
#           [ 1.7007e-01],
#           [-1.0038e+00],
#           [-1.4385e-02],
#           [-1.5797e-01],
#           [-9.7102e-01],
#           [-1.2108e-01],
#           [ 1.0059e+00],
#           [-1.7904e-01],
#           [ 1.6514e-01],
#           [ 5.9902e-01],
#           [-1.0712e+00],
#           [ 9.2236e-02],
#           [ 2.2042e+00],
#           [ 5.8172e-01],
#           [ 7.6794e-01],
#           [-2.5679e-01],
#           [ 2.0623e+00],
#           [ 1.0964e+00],
#           [-1.6274e+00],
#           [ 1.0397e+00],
#           [-1.1864e+00],
#           [-1.7700e-01],
#           [-4.4371e-01],
#           [ 8.6359e-01],
#           [-8.1912e-01],
#           [ 2.7248e-01],
#           [ 3.5897e-01],
#           [ 2.7583e-01],
#           [-5.2642e-01],
#           [-9.4528e-01],
#           [ 3.3981e-02],
#           [-7.4638e-02],
#           [ 3.2157e-01],
#           [ 3.3877e-01],
#           [ 3.3160e-01],
#           [ 1.1865e+00],
#           [-2.7094e-03],
#           [-5.4695e-01],
#           [ 2.8099e-01],
#           [-1.2422e+00],
#           [ 8.0261e-01],
#           [-1.4613e+00],
#           [ 1.2022e+00],
#           [-1.0766e+00],
#           [-2.6756e+00],
#           [ 2.0998e-01],
#           [-2.5171e+00],
#           [-8.3922e-01],
#           [ 3.7037e-01],
#           [-1.2379e-02],
#           [ 4.5847e-01],
#           [ 1.4844e+00],
#           [-5.8754e-03],
#           [ 5.6285e-02],
#           [ 2.1171e-01],
#           [ 1.8315e-02],
#           [-1.8209e-01],
#           [-1.1760e+00],
#           [ 8.5963e-01],
#           [-9.8313e-01],
#           [ 7.3366e-01],
#           [ 1.4661e+00],
#           [-1.4162e+00],
#           [-4.7735e-02],
#           [-6.0920e-01],
#           [-1.0321e+00],
#           [-4.7918e-01],
#           [ 5.3294e-01],
#           [ 9.8408e-01],
#           [-1.3566e+00],
#           [ 3.4299e-01],
#           [-4.1514e-01],
#           [-8.8933e-01],
#           [-7.2819e-01],
#           [ 1.4667e-01],
#           [-1.1924e+00],
#           [ 3.9641e-01],
#           [-3.2134e-01],
#           [-1.1077e+00],
#           [ 1.2191e+00],
#           [ 4.8816e-01],
#           [-1.0872e+00],
#           [ 9.8152e-01],
#           [-3.8281e-01],
#           [ 1.5607e+00],
#           [ 1.2403e-01],
#           [ 2.2987e+00],
#           [ 1.0227e+00],
#           [ 9.4195e-01],
#           [ 5.1178e-01],
#           [ 6.5523e-01],
#           [ 1.2592e+00],
#           [-9.0616e-01],
#           [ 1.5434e+00],
#           [-1.3305e+00],
#           [ 1.9523e-01],
#           [-4.9020e-01],
#           [-4.4116e-01],
#           [-4.9030e-01],
#           [ 9.6368e-01],
#           [-3.0488e-02],
#           [-1.3597e+00],
#           [-6.2498e-01],
#           [ 1.7460e+00],
#           [-4.4904e-01],
#           [-5.8653e-01],
#           [ 8.1195e-02],
#           [ 9.9426e-01],
#           [-6.8863e-01],
#           [ 1.1228e+00],
#           [ 4.1439e-01],
#           [ 8.5515e-01],
#           [-1.0694e+00],
#           [-2.2128e-01],
#           [-5.7377e-01],
#           [-8.2361e-01],
#           [ 1.4839e+00],
#           [-1.3187e+00],
#           [-3.3374e-01],
#           [-1.8515e+00],
#           [ 1.3256e+00],
#           [ 2.1973e+00],
#           [-1.7755e+00],
#           [ 6.8488e-01],
#           [-1.0117e+00],
#           [ 2.7004e-01],
#           [ 4.8443e-01],
#           [-3.1106e-01],
#           [-2.3314e+00],
#           [-1.8419e+00],
#           [ 7.5587e-01],
#           [-8.9821e-01],
#           [-5.5424e-01],
#           [ 1.6575e+00],
#           [-1.5922e+00],
#           [-8.1211e-01],
#           [-4.8266e-01],
#           [-3.2983e-01],
#           [ 1.8861e+00],
#           [-8.2212e-03],
#           [-1.9400e+00],
#           [-3.5627e-01],
#           [-8.8407e-01],
#           [ 5.9820e-02],
#           [ 5.5325e-01],
#           [ 1.1563e+00],
#           [-1.3117e+00],
#           [-1.9444e+00],
#           [ 3.7273e-01],
#           [ 1.3566e+00],
#           [-1.4729e+00],
#           [ 7.8171e-01],
#           [-1.3662e+00],
#           [ 3.6438e-01],
#           [ 2.0415e+00],
#           [ 2.3045e-01],
#           [-2.5794e-01],
#           [ 2.4778e+00],
#           [-9.4289e-01],
#           [ 1.9219e-02],
#           [-5.1167e-03],
#           [-4.2666e-01],
#           [-1.4454e+00],
#           [ 2.0364e+00],
#           [ 2.0019e-01],
#           [-1.6333e-01],
#           [ 1.4917e+00],
#           [-1.4533e+00],
#           [-1.7947e-01],
#           [-8.9603e-01],
#           [-8.8477e-01],
#           [ 9.3198e-01],
#           [ 2.1408e-01],
#           [-5.1960e-01],
#           [ 2.7064e-01],
#           [ 8.3038e-01],
#           [-1.2472e+00],
#           [ 8.3336e-02],
#           [ 3.8414e-01],
#           [-1.1829e+00],
#           [-1.1438e+00],
#           [-8.2523e-01],
#           [-5.8382e-01],
#           [ 1.8112e+00],
#           [ 1.9060e+00],
#           [-2.3523e-01],
#           [-5.7208e-01],
#           [-3.9752e-01],
#           [ 4.9316e-01],
#           [-2.3533e-01],
#           [-2.8415e-01],
#           [ 1.5240e+00],
#           [ 1.1824e+00],
#           [ 3.2356e-01],
#           [-7.4837e-01],
#           [ 5.0991e-01],
#           [-7.1831e-02],
#           [ 6.6651e-01],
#           [ 5.4217e-01],
#           [ 2.1849e-01],
#           [-1.9415e+00],
#           [-5.0752e-01],
#           [ 1.3114e+00],
#           [-5.2634e-01],
#           [-1.0249e+00],
#           [-1.4594e+00],
#           [-4.1211e-01],
#           [ 6.7818e-02],
#           [ 1.1387e+00],
#           [ 1.2422e+00],
#           [-3.9826e-01],
#           [ 1.2045e+00],
#           [ 5.5368e-01],
#           [-3.4975e-01],
#           [-9.2094e-01],
#           [ 9.3061e-01],
#           [-8.0687e-01],
#           [-7.7822e-01],
#           [-8.8894e-01],
#           [-2.7203e-01],
#           [ 6.7865e-01],
#           [-6.1394e-01],
#           [-3.5200e-01],
#           [-9.1395e-01],
#           [ 9.3520e-01],
#           [-3.3159e-01],
#           [-2.9378e+00],
#           [ 1.5225e+00],
#           [-9.5193e-01],
#           [-6.1885e-01],
#           [ 2.6719e+00]]]])
# tensor([[ 0.0128,  0.0281, -0.0142,  0.0187,  0.0453]],
#        grad_fn=<AddmmBackward>)
